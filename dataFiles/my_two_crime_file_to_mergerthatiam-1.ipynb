# %% [markdown]
# # Import requests and Beautifulsoup to web srape from a website to get my crime data for 52 states from 2011 to 2020

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_violent_crime_rate"
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    
    table = soup.find('table', {'class': 'wikitable'})

# %% [markdown]
# # pulling all data from the website for all the data of all years and saved to violent_crime_rates_all_years.csv

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_violent_crime_rate"
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    
    table = soup.find('table', {'class': 'wikitable'})


    with open('violent_crime_rates_all_years.csv', 'w', newline='', encoding='utf-8') as csvfile:
        csv_writer = csv.writer(csvfile)

        
        header = ['State']
        header.extend([year.text.strip() for year in table.find_all('th')[2:]])
        csv_writer.writerow(header)

        
        for row in table.find_all('tr')[2:]:  
            columns = row.find_all(['th', 'td'])  

            if len(columns) > 1:  
                state = columns[0].text.strip()
                rates = [column.text.strip() for column in columns[1:]]
                csv_writer.writerow([state] + rates)

    print("Data for all years has been successfully saved to 'violent_crime_rates_all_years.csv'.")

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Data for all years has been successfully saved to 'violent_crime_rates_all_years.csv'.

# %% [markdown]
# # open the csv file to read

# %%
import csv

with open('violent_crime_rates_all_years.csv', 'r', newline='', encoding='utf-8') as csvfile:

    csv_reader = csv.reader(csvfile)

    for row in csv_reader:
        print(row)
# Out:
# ['State', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '', '', '', '', '', '', '', '', '', '', '', '', 'United States\u202f*', '1,313,105', '398.5', '379.4', '383.4', '394.0', '397.5', '383.2', '372.0', '367.9', '387.8', '386.3']
# ['Washington\u202f* D.C.', '7,127', '999.8', '1045.2', '997.1', '1002.7', '1203.5', '1269.1', '1242.6', '1281.9', '1241.8', '1202.1']
# ['Alaska\u202f*', '6,126', '837.8', '865.0', '891.7', '856.7', '804.6', '730.2', '635.5', '602.6', '604.1', '606.5']
# ['New Mexico\u202f*', '16,393', '778.3', '824.0', '842.8', '778.6', '699.4', '656.1', '597.7', '596.7', '559.6', '567.5']
# ['Tennessee\u202f*', '46,328', '672.7', '598.9', '630.4', '655.0', '638.5', '612.1', '610.7', '579.7', '638.5', '608.2']
# ['Arkansas\u202f*', '20,363', '671.9', '580.8', '561.6', '566.0', '554.3', '521.3', '480.2', '445.7', '469.6', '480.9']
# ...

# %% [markdown]
# # install tabulate to format my dateframe in  readable format

# %%
pip install tabulate
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: tabulate in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.9.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# # Read the CSV file into a DataFrame and save DataFrame to new name and display the first few rows of the DataFrame

# %%
import pandas as pd

new_violent_crime = pd.read_csv('violent_crime_rates_all_years.csv')


print(new_violent_crime.head())
# Out:
#                State    2020   2019    2018   2017    2016    2015    2014  \
# 0  Washington * D.C.   7,127  999.8  1045.2  997.1  1002.7  1203.5  1269.1
# 1           Alaska *   6,126  837.8   865.0  891.7   856.7   804.6   730.2
# 2       New Mexico *  16,393  778.3   824.0  842.8   778.6   699.4   656.1
# 3        Tennessee *  46,328  672.7   598.9  630.4   655.0   638.5   612.1
# 4         Arkansas *  20,363  671.9   580.8  561.6   566.0   554.3   521.3
#
#      2013    2012  ...  398.5  379.4  383.4  394.0  397.5  383.2  372.0  \
# 0  1242.6  1281.9  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   635.5   602.6  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2   597.7   596.7  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3   610.7   579.7  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4   480.2   445.7  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    367.9  387.8  386.3
# 0    NaN    NaN    NaN
# 1    NaN    NaN    NaN
# ...

# %% [markdown]
# # Read the csv file into a pandas DataFrame, keep the columns i want to keep

# %%
import pandas as pd
file_path = 'violent_crime_rates_all_years.csv'

new_violent_crime= pd.read_csv(file_path)

columns_to_keep = ['State', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011']

new_violent_crime = new_violent_crime[columns_to_keep]

# %% [markdown]
# #Print out the DataFrame out

# %%
print(new_violent_crime)
# Out:
#                 State       2020   2019    2018   2017    2016    2015  \
# 0   Washington * D.C.      7,127  999.8  1045.2  997.1  1002.7  1203.5
# 1            Alaska *      6,126  837.8   865.0  891.7   856.7   804.6
# 2        New Mexico *     16,393  778.3   824.0  842.8   778.6   699.4
# 3         Tennessee *     46,328  672.7   598.9  630.4   655.0   638.5
# 4          Arkansas *     20,363  671.9   580.8  561.6   566.0   554.3
# 5           Arizona *     35,980  654.8   447.1  475.7   505.7   471.0
# 6         Louisiana *     29,704  639.4   559.7  543.3   556.3   565.0
# 7          Missouri *     33,385  542.7   499.6  501.4   531.2   520.8
# 8    South Carolina *     27,691  530.7   510.1  500.8   506.1   506.8
# 9      South Dakota *      4,476  501.4   397.1  396.4   429.8   422.0
# 10         Michigan *     47,641  478.0   438.6  452.5   449.9   460.9
# 11          Montana *      5,077  469.8   417.9  380.9   373.9   374.1
# ...

# %% [markdown]
# # Save to a new to csv file and select my files and clean the column names to show cleaned dataframe called newer_cleaned_violent_crime_rates

# %% [markdown]
# # Had reopen DataFrame and rename it because I forgot to do a few things with the DataFrame

# %%
newer_cleaned_violent_crime_rates = pd.read_csv('new_cleaned_violent_crime_rates.csv')
newer_cleaned_violent_crime_rates
# Out:
#                 State       2020   2019    2018   2017    2016    2015  \
# 0   Washington * D.C.      7,127  999.8  1045.2  997.1  1002.7  1203.5
# 1            Alaska *      6,126  837.8   865.0  891.7   856.7   804.6
# 2        New Mexico *     16,393  778.3   824.0  842.8   778.6   699.4
# 3         Tennessee *     46,328  672.7   598.9  630.4   655.0   638.5
# 4          Arkansas *     20,363  671.9   580.8  561.6   566.0   554.3
# 5           Arizona *     35,980  654.8   447.1  475.7   505.7   471.0
# 6         Louisiana *     29,704  639.4   559.7  543.3   556.3   565.0
# 7          Missouri *     33,385  542.7   499.6  501.4   531.2   520.8
# 8    South Carolina *     27,691  530.7   510.1  500.8   506.1   506.8
# 9      South Dakota *      4,476  501.4   397.1  396.4   429.8   422.0
# 10         Michigan *     47,641  478.0   438.6  452.5   449.9   460.9
# 11          Montana *      5,077  469.8   417.9  380.9   373.9   374.1
# ...

# %% [markdown]
# #Remove the * from the DataFrame state column

# %%
newer_cleaned_violent_crime_rates['State'] = newer_cleaned_violent_crime_rates['State'].str.replace('*', '')

# %% [markdown]
# #Display the DataFrame

# %%
newer_cleaned_violent_crime_rates
# Out:
#                State       2020   2019    2018   2017    2016    2015    2014  \
# 0   Washington  D.C.      7,127  999.8  1045.2  997.1  1002.7  1203.5  1269.1
# 1            Alaska       6,126  837.8   865.0  891.7   856.7   804.6   730.2
# 2        New Mexico      16,393  778.3   824.0  842.8   778.6   699.4   656.1
# 3         Tennessee      46,328  672.7   598.9  630.4   655.0   638.5   612.1
# 4          Arkansas      20,363  671.9   580.8  561.6   566.0   554.3   521.3
# 5           Arizona      35,980  654.8   447.1  475.7   505.7   471.0   410.2
# 6         Louisiana      29,704  639.4   559.7  543.3   556.3   565.0   539.7
# 7          Missouri      33,385  542.7   499.6  501.4   531.2   520.8   497.4
# 8    South Carolina      27,691  530.7   510.1  500.8   506.1   506.8   504.5
# 9      South Dakota       4,476  501.4   397.1  396.4   429.8   422.0   383.1
# 10         Michigan      47,641  478.0   438.6  452.5   449.9   460.9   415.5
# ...

# %% [markdown]
# # So I extract the United states row out of my DatFrame and saved that United States row into a new csv file called single_united_states_row.csv so that I can merge that with my other crime csv file
# #

# %%
import pandas as pd

single_row_crime = newer_cleaned_violent_crime_rates.loc[52]
single_row_crime.to_csv('single_united_states_row.csv', index=False)

newer_cleaned_violent_crime_rates = newer_cleaned_violent_crime_rates.drop(52)

# %% [markdown]
# # Removed the 52 that was the United States crime rate numbers

# %%
newer_cleaned_violent_crime_rates = newer_cleaned_violent_crime_rates[newer_cleaned_violent_crime_rates['State'] != 'United States']

# %%
newer_cleaned_violent_crime_rates
# Out:
#                State     2020   2019    2018   2017    2016    2015    2014  \
# 0   Washington  D.C.    7,127  999.8  1045.2  997.1  1002.7  1203.5  1269.1
# 1            Alaska     6,126  837.8   865.0  891.7   856.7   804.6   730.2
# 2        New Mexico    16,393  778.3   824.0  842.8   778.6   699.4   656.1
# 3         Tennessee    46,328  672.7   598.9  630.4   655.0   638.5   612.1
# 4          Arkansas    20,363  671.9   580.8  561.6   566.0   554.3   521.3
# 5           Arizona    35,980  654.8   447.1  475.7   505.7   471.0   410.2
# 6         Louisiana    29,704  639.4   559.7  543.3   556.3   565.0   539.7
# 7          Missouri    33,385  542.7   499.6  501.4   531.2   520.8   497.4
# 8    South Carolina    27,691  530.7   510.1  500.8   506.1   506.8   504.5
# 9      South Dakota     4,476  501.4   397.1  396.4   429.8   422.0   383.1
# 10         Michigan    47,641  478.0   438.6  452.5   449.9   460.9   415.5
# ...

# %% [markdown]
# # Pulled up the the states with the highest crime rate for each year using convert_to_numeric(value) to handle non-strings

# %%
import pandas as pd

columns_to_convert = ['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011']

def convert_to_numeric(value):
    try:
        return pd.to_numeric(value.replace(',', ''), errors='coerce')
    except AttributeError:
        return pd.to_numeric(value, errors='coerce')

for column in columns_to_convert:
    newer_cleaned_violent_crime_rates[column] = newer_cleaned_violent_crime_rates[column].apply(convert_to_numeric)

newer_cleaned_violent_crime_rates = newer_cleaned_violent_crime_rates.fillna(0)


for column in columns_to_convert:
    highest_crime_state = newer_cleaned_violent_crime_rates.loc[newer_cleaned_violent_crime_rates[column].idxmax(), 'State']
    print(f"State with the highest crime rate in {column}: {highest_crime_state}")
# Out:
# State with the highest crime rate in 2020: California
# State with the highest crime rate in 2019: Washington  D.C.
# State with the highest crime rate in 2018: Washington  D.C.
# State with the highest crime rate in 2017: Washington  D.C.
# State with the highest crime rate in 2016: Washington  D.C.
# State with the highest crime rate in 2015: Washington  D.C.
# State with the highest crime rate in 2014: Washington  D.C.
# State with the highest crime rate in 2013: Washington  D.C.
# State with the highest crime rate in 2012: Washington  D.C.
# State with the highest crime rate in 2011: Washington  D.C.

# %% [markdown]
# # Pulled up the the states with the lowest crime rate for each year using convert_to_numeric(value) to handle non-strings

# %%
import pandas as pd

columns_to_convert = ['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011']

def convert_to_numeric(value):
    try:
        return pd.to_numeric(value.replace(',', ''), errors='coerce')
    except AttributeError:
        return pd.to_numeric(value, errors='coerce')

for column in columns_to_convert:
    newer_cleaned_violent_crime_rates[column] = newer_cleaned_violent_crime_rates[column].apply(convert_to_numeric)

newer_cleaned_violent_crime_rates = newer_cleaned_violent_crime_rates.fillna(0)

for column in columns_to_convert:
    lowest_crime_state = newer_cleaned_violent_crime_rates.loc[newer_cleaned_violent_crime_rates[column].idxmin(), 'State']
    print(f"State with the lowest crime rate in {column}: {lowest_crime_state}")
# Out:
# State with the lowest crime rate in 2020: Vermont
# State with the lowest crime rate in 2019: Maine
# State with the lowest crime rate in 2018: Maine
# State with the lowest crime rate in 2017: Maine
# State with the lowest crime rate in 2016: Maine
# State with the lowest crime rate in 2015: Maine
# State with the lowest crime rate in 2014: Vermont
# State with the lowest crime rate in 2013: Vermont
# State with the lowest crime rate in 2012: Vermont
# State with the lowest crime rate in 2011: Maine

# %% [markdown]
# # Open dateFiles\crimes.dataset.csv file

# %%
crime= pd.read_csv("dataFiles\crimes.dataset.csv")
 
crime
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 0   2000  281,421,906      1,425,486               506.5
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 3   2003  290,788,976      1,383,676               475.8
# 4   2004  293,656,842      1,360,088               463.2
# 5   2005  296,507,061      1,390,745               469.0
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 11  2011  311,587,816      1,206,005               387.1
# 12  2012  313,873,685      1,217,057               387.8
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# ...

# %% [markdown]
# #Use drop to remove columns in my DataFrame

# %%
columns_to_remove = [
    'Murder nonnegligent manslaughter rate',
    'Rape\n(revised\ndefinition)',
    'Rape\n(revised\ndefinition)\nrate',
    'Rape\n(legacy\ndefinition)\nrate',
    'Robbery\nrate',
    'Aggravated\nassault rate',
    'Property\ncrime',
    'Property\ncrime\nrate',
    'Larceny-\ntheft rate',
    'Motor\nvehicle\ntheft',
    'Motor\nvehicle\ntheft\nrate',
    'Burglary\nrate',
    'Violent crime rate',
    'Aggravated\nassault',
    'Larceny-\ntheft',
    'Murder nonnegligent manslaughter',
    'Rape\n(legacy\ndefinition',
    'Robbery',
    'Burglary',
    
]

crime= crime.drop(columns=columns_to_remove)
crime
# Out:
#     Year   Population Violent Crimes
# 0   2000  281,421,906      1,425,486
# 1   2001  285,317,559      1,439,480
# 2   2002  287,973,924      1,423,677
# 3   2003  290,788,976      1,383,676
# 4   2004  293,656,842      1,360,088
# 5   2005  296,507,061      1,390,745
# 6   2006  299,398,484      1,435,123
# 7   2007  301,621,157      1,422,970
# 8   2008  304,059,724      1,394,461
# 9   2009  307,006,550      1,325,896
# 10  2010  309,330,219      1,251,248
# 11  2011  311,587,816      1,206,005
# 12  2012  313,873,685      1,217,057
# 13  2013  316,497,531      1,168,298
# 14  2014  318,907,401      1,153,022
# 15  2015  320,896,618      1,199,310
# 16  2016  323,405,935      1,250,162
# 17  2017  325,147,121      1,247,917
# 18  2018  326,687,501      1,209,997
# 19  2019  328,239,523      1,203,808

# %% [markdown]
# #Save to the cleaned up DataFrame to a new csv file so that i can merge two files together

# %%
import pandas as pd

crime.to_csv('population_crime_rate.csv', index=False)

# %%
import pandas as pd

population_crime = pd.read_csv('population_crime_rate.csv')

population_crime
# Out:
#     Year   Population Violent Crimes
# 0   2000  281,421,906      1,425,486
# 1   2001  285,317,559      1,439,480
# 2   2002  287,973,924      1,423,677
# 3   2003  290,788,976      1,383,676
# 4   2004  293,656,842      1,360,088
# 5   2005  296,507,061      1,390,745
# 6   2006  299,398,484      1,435,123
# 7   2007  301,621,157      1,422,970
# 8   2008  304,059,724      1,394,461
# 9   2009  307,006,550      1,325,896
# 10  2010  309,330,219      1,251,248
# 11  2011  311,587,816      1,206,005
# 12  2012  313,873,685      1,217,057
# 13  2013  316,497,531      1,168,298
# 14  2014  318,907,401      1,153,022
# 15  2015  320,896,618      1,199,310
# 16  2016  323,405,935      1,250,162
# 17  2017  325,147,121      1,247,917
# 18  2018  326,687,501      1,209,997
# 19  2019  328,239,523      1,203,808

# %% [markdown]
# #Show DataFrame

# %%
single_row_crime
# Out:
# State    United States
# 2020          1,313,105
# 2019              398.5
# 2018              379.4
# 2017              383.4
# 2016              394.0
# 2015              397.5
# 2014              383.2
# 2013              372.0
# 2012              367.9
# 2011              387.8
# Name: 52, dtype: object

# %% [markdown]
# convert the dictionary to a DataFrame

# %%
import pandas as pd

data = {
    'State': [2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011],
    'United States': ['1,313,105', 398.5, 379.4, 383.4, 394.0, 397.5, 383.2, 372.0, 367.9, 387.8]
}

single_row_crime = pd.DataFrame(data)


print(single_row_crime)
# Out:
#    State United States
# 0   2020     1,313,105
# 1   2019         398.5
# 2   2018         379.4
# 3   2017         383.4
# 4   2016         394.0
# 5   2015         397.5
# 6   2014         383.2
# 7   2013         372.0
# 8   2012         367.9
# 9   2011         387.8

# %% [markdown]
# #Remove and drop rows

# %%
import pandas as pd

data = {
    'State': [2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011],
    'United States': ['1,313,105', 398.5, 379.4, 383.4, 394.0, 397.5, 383.2, 372.0, 367.9, 387.8]
}

single_row_crime = pd.DataFrame(data)

rows_to_remove = [1, 2, 3, 4, 5, 6, 7, 8, 9]

single_row_crime = single_row_crime.drop(rows_to_remove)


print(single_row_crime)
# Out:
#    State United States
# 0   2020     1,313,105

# %% [markdown]
# #Changed and rename the names of the two columns in the dataFrame so that I can merge my crime files

# %%
import pandas as pd

data = {
    'State': [2020],
    'United States': ['1,313,105']
}

single_row_crime = single_row_crime.rename(columns={'State': 'Year', 'United States': 'Violent Crimes'})

print(single_row_crime)
# Out:
#    Year Violent Crimes
# 0  2020      1,313,105

# %% [markdown]
# # Add A new column and put a value into that column

# %%
import pandas as pd

data = {'Year': [2020], 'Violent Crimes': [1313105]}
single_row_crime = pd.DataFrame(data)

single_row_crime.insert(1, "Population", "{:,}".format(335942111))

single_row_crime["Violent Crimes"] = single_row_crime["Violent Crimes"].apply(lambda x: "{:,}".format(x))
print(single_row_crime)
# Out:
#    Year   Population Violent Crimes
# 0  2020  335,942,111      1,313,105

# %% [markdown]
# #Save my DataFrame to a new csv file

# %%
single_row_crime.to_csv('cleaned_single_row_crime_file.csv', index=False)

# %% [markdown]
# #Saved my cleaned up DataFrame and made a new csv file
